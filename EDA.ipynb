# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Loading File

# %%
df_books = pd.read_json('./dataset/goodreads_books_comics_graphic.json', lines=True)

# %% [markdown]
# # Exploring Columns

# %%
print(df_books.columns)
# Out:
# Index(['isbn', 'text_reviews_count', 'series', 'country_code', 'language_code',
#        'popular_shelves', 'asin', 'is_ebook', 'average_rating', 'kindle_asin',
#        'similar_books', 'description', 'format', 'link', 'authors',
#        'publisher', 'num_pages', 'publication_day', 'isbn13',
#        'publication_month', 'edition_information', 'publication_year', 'url',
#        'image_url', 'book_id', 'ratings_count', 'work_id', 'title',
#        'title_without_series'],
#       dtype='object')

# %%
display(df_books[(df_books['title'].str.contains('Maus')) & (df_books['language_code']=='eng')])
# Out:
#              isbn  text_reviews_count    series country_code language_code  \
# 7452   0679729771                2337  [186594]           US           eng
# 7453   0394541553                4402  [186595]           US           eng
# 12750  0394747232                 508  [186595]           US           eng
# 70529  0590477021                   5  [186594]           US           eng
# 77599  0670916838                   7  [310835]           US           eng
# 83700  0679406417                 312  [310834]           US           eng
# 87428  0140104143                   6  [186595]           US           eng
#
#                                          popular_shelves asin is_ebook  \
# 7452   [{'count': '19510', 'name': 'to-read'}, {'coun...         false
# 7453   [{'count': '92915', 'name': 'to-read'}, {'coun...         false
# 12750  [{'count': '92941', 'name': 'to-read'}, {'coun...         false
# 70529  [{'count': '19514', 'name': 'to-read'}, {'coun...         false
# ...

# %% [markdown]
# ## Checking for repeated entries

# %%
display(df_books[(df_books['title'].str.contains('Maus')) & (df_books['language_code']=='eng')][['book_id','series','work_id','title']])
# Out:
#         book_id    series   work_id  \
# 7452      15197  [186594]   1782551
# 7453      15196  [186595]   1947012
# 12750     64229  [186595]   1947012
# 70529    182176  [186594]   1782551
# 77599  13041719  [310835]  15325080
# 83700    331692  [310834]   1658562
# 87428    988416  [186595]   1947012
#
#                                                    title
# 7452   Maus II: A Survivor's Tale: And Here My Troubl...
# 7453   Maus I: A Survivor's Tale: My Father Bleeds Hi...
# 12750  Maus: A Survivor's Tale : My Father Bleeds His...
# 70529  Maus II: A Survivor's Tale: And Here My Troubl...
# 77599                                           MetaMaus
# 83700  The Complete Maus: A Survivor's Tale (Maus, #1-2)
# 87428                             Maus A Survivor's Tale

# %% [markdown]
# # Exploring Features

# %% [markdown]
# * language_code

# %%
fig = px.histogram(df_books, x='language_code')
fig.show()

# %%
df_books[(df_books['language_code']=='') & (df_books['ratings_count']>5000)].head(5)
# Out:
#             isbn  text_reviews_count    series country_code language_code  \
# 439   1421527669                 119  [207525]           US
# 440   1421527677                  88  [207526]           US
# 2844  1607063298                 431  [404308]           US
# 5449  1421506718                  93  [277946]           US
# 5854  0833554549                 159  [242065]           US
#
#                                         popular_shelves asin is_ebook  \
# 439   [{'count': '2501', 'name': 'to-read'}, {'count...         false
# 440   [{'count': '1519', 'name': 'to-read'}, {'count...         false
# 2844  [{'count': '2438', 'name': 'to-read'}, {'count...         false
# 5449  [{'count': '725', 'name': 'to-read'}, {'count'...         false
# 5854  [{'count': '964', 'name': 'to-read'}, {'count'...         false
#
#       average_rating kindle_asin  ... publication_month edition_information  \
# 439             4.30  B00F3HJCKE  ...                 2
# ...

# %%
df_books[df_books['url']=='https://www.goodreads.com/book/show/6775624-black-bird-vol-03']
# Out:
#            isbn  text_reviews_count    series country_code language_code  \
# 439  1421527669                 119  [207525]           US
#
#                                        popular_shelves asin is_ebook  \
# 439  [{'count': '2501', 'name': 'to-read'}, {'count...         false
#
#      average_rating kindle_asin  ... publication_month edition_information  \
# 439             4.3  B00F3HJCKE  ...                 2
#
#     publication_year                                                url  \
# 439             2010  https://www.goodreads.com/book/show/6775624-bl...
#
#                                              image_url  book_id ratings_count  \
# 439  https://images.gr-assets.com/books/1314661728m...  6775624          9643
#
#      work_id                                 title  \
# 439  6976093  Black Bird, Vol. 03 (Black Bird, #3)
#
#                      title_without_series
# 439  Black Bird, Vol. 03 (Black Bird, #3)
#
# [1 rows x 29 columns]

# %%
fig = px.histogram(df_books[df_books['ratings_count']>1000], x='language_code')
fig.show()

# %% [markdown]
# * rating

# %%
fig = px.histogram(df_books, x='average_rating')
fig.show()

# %%
fig = px.histogram(df_books[df_books['ratings_count']>500], x='ratings_count')
fig.show()

# %%
fig = px.histogram(df_books[df_books['ratings_count']>500], x='average_rating')
fig.show()
